# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>
#
# # Statistics - Part 1

# %%
import numpy as np
import matplotlib.pyplot as plt
# get matplot to show charts inline
# %matplotlib inline

# %%
# frequency of some observations using pie chart
labels = 'Developers', 'Data Engineers', 'Data Scientists', 'Business Analysts'
frequency = [15, 32, 12, 7]
# can add another pie chart
#frequency1 = [30, 5, 9, 50]

fig1, ax1 = plt.subplots()
explode = (0, 0, 0, 0.3)  # exercise: modify this to "explode" only the 3rd slice (i.e. 'Data Scientists')

# ax1.pie(frequency, explode=explode, labels=labels)

# to add another pie chart, add the []
#ax[0].pie(frequency, explode=explode, labels=labels, autopct='%1.1f%%',
#        shadow=True, startangle=90)
#ax[0].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
#ax[0].set.title('Australia')

ax1.pie(frequency, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
# plot frequency of some observations using bar chart
objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]

# Create a bar plot of performance for each object
plt.xticks(y_pos, objects)
plt.bar(y_pos, performance)

# Use ylabel and title to label the y axis and provide a title
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
y_pos
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
plt.bar(y_pos, performance)
plt.xticks(y_pos, objects)
plt.bar(y_pos, performance)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2023 Institute of Data
#
#
# ---
#
#
#
# ---
